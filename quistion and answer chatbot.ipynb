# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
# %pip install langchain-groq
# Out:
# Requirement already satisfied: langchain-groq in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.1.3)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-groq) (0.37.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-groq) (1.4.8)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.14.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (2.13.4)
# Requirement already satisfied: sniffio in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in C:\Users\Muhammad Zain Ul Aba\AppData\Roaming\Python\Python314\site-packages (from groq<1.0.0,>=0.30.0->langchain-groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from anyio<5,>=3.5.0->groq<1.0.0,>=0.30.0->langchain-groq) (3.18)
# Requirement already satisfied: certifi in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.9.3)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.16.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.8.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3,>=1.9.0->groq<1.0.0,>=0.30.0->langchain-groq) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\Muhammad Zain Ul Aba\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain-groq) (2.7.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_groq import ChatGroq
llm = ChatGroq(model="llama-3.3-70b-versatile")

# %%
zain = llm.invoke("who is pm of Pakistan")
zain
# Out:
# AIMessage(content='The current Prime Minister of Pakistan is Shehbaz Sharif. He took office on April 11, 2022, after the ouster of Imran Khan through a vote of no confidence.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 41, 'prompt_tokens': 40, 'total_tokens': 81, 'completion_time': 0.08534275, 'completion_tokens_details': None, 'prompt_time': 0.001983205, 'prompt_tokens_details': None, 'queue_time': 0.00815499, 'total_time': 0.087325955}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019f1174-80ba-77c0-82f6-936e243a2cda-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 41, 'total_tokens': 81})

# %%
zain = llm.invoke("pakistan ka konsa sooba ziayada bara h ?")
print(zain.content)
# Out:
# Pakistan ka sab se bada sooba Balochistan hai.
